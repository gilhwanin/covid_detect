# %% [markdown]
# #video classification (1) of COVID-US (data preparation)

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2019/09/step-by-step-deep-learning-tutorial-video-classification-python/

# %% [markdown]
# **preprocessed(clean) videos -> split -> pre-trained CNN** -> LSTM or GRU -> dense layer -> result(accuracy)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/COVID-US-main/COVID-US-main
# Out:
# /content/drive/MyDrive/COVID-US-main/COVID-US-main

# %%
route = '/content/drive/MyDrive/COVID-US-main/COVID-US-main/'

# %% [markdown]
# ##0. Import libraries

# %%
import cv2 # for capturing videos
import math # for mathematical operations
# %matplotlib inline
import matplotlib.pyplot as plt # for plotting the images
import numpy as np # for mathematical operations
import pandas as pd
import tensorflow as tf

from skimage.transform import resize # for resizing images
from sklearn.model_selection import train_test_split
from glob import glob
from tqdm import tqdm

import keras
from keras.utils import np_utils
from keras.preprocessing import image # for preprocessing the images
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.layers import Dense, InputLayer, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D
from keras.layers import TimeDistributed, GRU, LSTM, GlobalAveragePooling1D

from scipy import stats as s
from sklearn.metrics import accuracy_score

import os
import time
import random
import PIL
from PIL import Image
# import re
# import shutil

# %%
frames=14
width=224
height=224
channels=3
train_test_ratio=0.3
train_val_ratio=0.2

# %% [markdown]
# ##1. Prepare preprocessd(clean) videos

# %%
video_dataset = pd.read_csv("utils/video_files_clean_properties_addition.csv")
video_dataset
# Out:
#                                    filename  framerate  ...  disease  source
# 0    1_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 1    2_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 2    3_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 3    4_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 4    5_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# ..                                      ...        ...  ...      ...     ...
# 237   239_paper_normal_prc_convex_clean.avi       15.0  ...        2       8
# 238    240_paper_other_prc_convex_clean.avi       15.0  ...        2       8
# 239    241_paper_other_prc_convex_clean.avi       15.0  ...        2       8
# 240    242_paper_other_prc_convex_clean.avi       15.0  ...        2       8
# 241    243_paper_other_prc_convex_clean.avi       15.0  ...        2       8
#
# [242 rows x 8 columns]

# %%
video_dataset=video_dataset[video_dataset['filename'].str.contains('covid|pneumonia|normal')]
video_dataset=video_dataset[video_dataset['filename'].str.contains('convex')]

video_dataset['disease'].value_counts()
# Out:
# 0    63
# 1    40
# 2    19
# Name: disease, dtype: int64

# %%
# separating the target
X = video_dataset
y = video_dataset['disease']

# creating the training and validation set
X_training, X_test, y_training, y_test = train_test_split(X, y, test_size=train_test_ratio, stratify = y)
X_train, X_val, y_train, y_val = train_test_split(X_training, y_training, shuffle=True, test_size=train_val_ratio, stratify = y_training)

X_train = X_train.reset_index(drop = True)
X_val = X_val.reset_index(drop = True)
X_test = X_test.reset_index(drop = True)
y_train = y_train.reset_index(drop = True)
y_val = y_val.reset_index(drop = True)
y_test = y_test.reset_index(drop = True)

# %%
aaa = video_dataset 
video_dataset = X_train

# %%
normal_dataset = video_dataset[video_dataset['filename'].str.contains('normal')]
normal_dataset.reset_index(drop = True)
normal_dataset
# Out:
#                                      filename  framerate  ...  disease  source
# 3   71_pocusatlas_normal_prc_convex_clean.avi       15.0  ...        2       4
# 13    236_clarius_normal_prc_convex_clean.avi       15.0  ...        2       9
# 21      152_radio_normal_prc_convex_clean.avi       15.0  ...        2       5
# 22    224_clarius_normal_prc_convex_clean.avi       15.0  ...        2       9
# 23  77_pocusatlas_normal_prc_convex_clean.avi       15.0  ...        2       4
# 32         190_uf_normal_prc_convex_clean.avi       15.0  ...        2       7
# 41         177_uf_normal_prc_convex_clean.avi       15.0  ...        2       7
# 45      239_paper_normal_prc_convex_clean.avi       15.0  ...        2       8
# 46         191_uf_normal_prc_convex_clean.avi       15.0  ...        2       7
# 57   20_butterfly_normal_prc_convex_clean.avi       15.0  ...        2       1
# 58   21_butterfly_normal_prc_convex_clean.avi       15.0  ...        2       1
#
# [11 rows x 8 columns]

# %%
covid_dataset = video_dataset[video_dataset['filename'].str.contains('covid')]
covid_dataset.reset_index(drop = True)
covid_dataset
# Out:
#                                     filename  framerate  ...  disease  source
# 0     220_clarius_covid_prc_convex_clean.avi       15.0  ...        0       9
# 2      42_grepmed_covid_prc_convex_clean.avi       15.0  ...        0       2
# 5    12_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 6    89_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 10  74_pocusatlas_covid_prc_convex_clean.avi       15.0  ...        0       4
# 14   17_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 15      200_paper_covid_prc_convex_clean.avi       15.0  ...        0       8
# 16   14_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 17   11_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 19   16_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 24   90_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 25    7_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 26    218_clarius_covid_prc_convex_clean.avi       15.0  ...        0       9
# 27      201_paper_covid_prc_convex_clean.avi       15.0  ...        0       8
# 29     35_grepmed_covid_prc_convex_clean.avi       15.0  ...        0       2
# 30   13_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 31  61_pocusatlas_covid_prc_convex_clean.avi       15.0  ...        0       4
# 35   94_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 36     24_grepmed_covid_prc_convex_clean.avi       15.0  ...        0       2
# 37    221_clarius_covid_prc_convex_clean.avi       15.0  ...        0       9
# 38     26_grepmed_covid_prc_convex_clean.avi       15.0  ...        0       2
# 40     31_grepmed_covid_prc_convex_clean.avi       15.0  ...        0       2
# 42      199_paper_covid_prc_convex_clean.avi       15.0  ...        0       8
# 44  51_pocusatlas_covid_prc_convex_clean.avi       15.0  ...        0       4
# 47      205_paper_covid_prc_convex_clean.avi       15.0  ...        0       8
# 48      202_paper_covid_prc_convex_clean.avi       15.0  ...        0       8
# 49    2_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 51    1_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 55  54_pocusatlas_covid_prc_convex_clean.avi       15.0  ...        0       4
# 59  49_pocusatlas_covid_prc_convex_clean.avi       15.0  ...        0       4
# 62   84_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 64  56_pocusatlas_covid_prc_convex_clean.avi       15.0  ...        0       4
# 65   91_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 66   92_butterfly_covid_prc_convex_clean.avi       15.0  ...        0       1
# 67      203_paper_covid_prc_convex_clean.avi       15.0  ...        0       8
#
# [35 rows x 8 columns]

# %%
pneumonia_dataset = video_dataset[video_dataset['filename'].str.contains('pneumonia')]
pneumonia_dataset.reset_index(drop = True)
pneumonia_dataset
# Out:
#                                         filename  framerate  ...  disease  source
# 1          184_uf_pneumonia_prc_convex_clean.avi       15.0  ...        1       7
# 4      37_grepmed_pneumonia_prc_convex_clean.avi       15.0  ...        1       2
# 7       131_litfl_pneumonia_prc_convex_clean.avi       15.0  ...        1       3
# 8   68_pocusatlas_pneumonia_prc_convex_clean.avi       15.0  ...        1       4
# 9   72_pocusatlas_pneumonia_prc_convex_clean.avi       15.0  ...        1       4
# 11      151_litfl_pneumonia_prc_convex_clean.avi       15.0  ...        1       3
# 12      153_radio_pneumonia_prc_convex_clean.avi       15.0  ...        1       5
# 18       158_core_pneumonia_prc_convex_clean.avi       15.0  ...        1       6
# 20      123_litfl_pneumonia_prc_convex_clean.avi       15.0  ...        1       3
# 28    232_clarius_pneumonia_prc_convex_clean.avi       15.0  ...        1       9
# 33      129_litfl_pneumonia_prc_convex_clean.avi       15.0  ...        1       3
# 34     25_grepmed_pneumonia_prc_convex_clean.avi       15.0  ...        1       2
# 39  79_pocusatlas_pneumonia_prc_convex_clean.avi       15.0  ...        1       4
# 43     38_grepmed_pneumonia_prc_convex_clean.avi       15.0  ...        1       2
# 50  64_pocusatlas_pneumonia_prc_convex_clean.avi       15.0  ...        1       4
# 52      121_litfl_pneumonia_prc_convex_clean.avi       15.0  ...        1       3
# 53     27_grepmed_pneumonia_prc_convex_clean.avi       15.0  ...        1       2
# 54      127_litfl_pneumonia_prc_convex_clean.avi       15.0  ...        1       3
# 56    234_clarius_pneumonia_prc_convex_clean.avi       15.0  ...        1       9
# 60       170_core_pneumonia_prc_convex_clean.avi       15.0  ...        1       6
# 61  80_pocusatlas_pneumonia_prc_convex_clean.avi       15.0  ...        1       4
# 63       43_litfl_pneumonia_prc_convex_clean.avi       15.0  ...        1       3
#
# [22 rows x 8 columns]

# %%
import shutil
files = glob('data/video/clean_copy2/*')
for f in files:
    os.remove(f)
os.rmdir("data/video/clean_copy2")
shutil.copytree("data/video/clean", "data/video/clean_copy2")
# Out:
# 'data/video/clean_copy2'

# %%
normal_aug_file_list = []
SEED_0 = 777
SEED_1 = 7777
SEED_2 = 77777
SEED_3 = 777777
angle = 15
for each_video in normal_dataset['filename']:
    cap = cv2.VideoCapture('data/video/clean/' + each_video)
    frameFPS = cap.get(cv2.CAP_PROP_FPS)
    frameWidth = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frameHeight = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"DIVX") # codec
    filename = 'data/video/clean_copy2/' + each_video
    index = filename.find('.avi')
    aug_0_filename = filename[:index] + '_aug_0' + filename[index:]
    aug_1_filename = filename[:index] + '_aug_1' + filename[index:]
    aug_2_filename = filename[:index] + '_aug_2' + filename[index:]
    aug_3_filename = filename[:index] + '_aug_3' + filename[index:]
    aug_4_filename = filename[:index] + '_aug_4' + filename[index:]
    normal_aug_file_list.append(aug_0_filename.split('/')[-1])
    normal_aug_file_list.append(aug_1_filename.split('/')[-1])
    normal_aug_file_list.append(aug_2_filename.split('/')[-1])
    normal_aug_file_list.append(aug_3_filename.split('/')[-1])
    normal_aug_file_list.append(aug_4_filename.split('/')[-1])
    videoWriter_0 = cv2.VideoWriter(aug_0_filename, fourcc, frameFPS, (frameWidth, frameHeight))
    videoWriter_1 = cv2.VideoWriter(aug_1_filename, fourcc, frameFPS, (frameWidth, frameHeight))
    videoWriter_2 = cv2.VideoWriter(aug_2_filename, fourcc, frameFPS, (frameWidth, frameHeight))
    videoWriter_3 = cv2.VideoWriter(aug_3_filename, fourcc, frameFPS, (frameWidth, frameHeight))
    videoWriter_4 = cv2.VideoWriter(aug_4_filename, fourcc, frameFPS, (frameWidth, frameHeight))

    while (cap.isOpened()):
        ret, frame = cap.read()
        if frame is None:
          break
        frame_0 = cv2.flip(frame,1)
        videoWriter_0.write(frame_0)

        random.seed(SEED_0)
        rand_angle = int(random.uniform(-angle,angle))
        h, w = frame.shape[:2]
        M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rand_angle, 1)
        frame_1 = cv2.warpAffine(frame, M, (w, h))
        frame_1 = np.uint8(frame_1)
        videoWriter_1.write(frame_1)
        
        random.seed(SEED_1)
        rand_angle = int(random.uniform(-angle,angle))
        h, w = frame.shape[:2]
        M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rand_angle, 1)
        frame_2 = cv2.warpAffine(frame, M, (w, h))
        frame_2 = np.uint8(frame_2)
        videoWriter_2.write(frame_2)

        random.seed(SEED_2)
        rand_angle = int(random.uniform(-angle,angle))
        h, w = frame.shape[:2]
        M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rand_angle, 1)
        frame_3 = cv2.warpAffine(frame, M, (w, h))
        frame_3 = np.uint8(frame_3)
        videoWriter_3.write(frame_3)

        random.seed(SEED_3)
        rand_angle = int(random.uniform(-angle,angle))
        h, w = frame.shape[:2]
        M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rand_angle, 1)
        frame_4 = cv2.warpAffine(frame, M, (w, h))
        frame_4 = np.uint8(frame_4)
        videoWriter_4.write(frame_4)
  
    cap.release()
    videoWriter_0.release()
    videoWriter_1.release()
    videoWriter_2.release()
    videoWriter_3.release()
    videoWriter_4.release()

    SEED_0 = SEED_0+1
    SEED_1 = SEED_1+1
    SEED_2 = SEED_2+1
    SEED_3 = SEED_3+1

# %%
covid_aug_file_list = []
for each_video in covid_dataset['filename']:
    cap = cv2.VideoCapture('data/video/clean/' + each_video)
    frameFPS = cap.get(cv2.CAP_PROP_FPS)
    frameWidth = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frameHeight = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"DIVX") # codec
    filename = 'data/video/clean_copy2/' + each_video
    index = filename.find('.avi')
    aug_0_filename = filename[:index] + '_aug_0' + filename[index:]
    covid_aug_file_list.append(aug_0_filename.split('/')[-1])
    videoWriter_0 = cv2.VideoWriter(aug_0_filename, fourcc, frameFPS, (frameWidth, frameHeight))

    while (cap.isOpened()):
        ret, frame = cap.read()
        frame_0 = cv2.flip(frame,1)
        if frame is None:
            break
        videoWriter_0.write(frame_0)
  
    cap.release()
    videoWriter_0.release()

# %%
pneumonia_aug_file_list = []
SEED = 888
angle = 15
for each_video in pneumonia_dataset['filename']:
    cap = cv2.VideoCapture('data/video/clean/' + each_video)
    frameFPS = cap.get(cv2.CAP_PROP_FPS)
    frameWidth = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frameHeight = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"DIVX") # codec
    filename = 'data/video/clean_copy2/' + each_video
    index = filename.find('.avi')
    aug_0_filename = filename[:index] + '_aug_0' + filename[index:]
    aug_1_filename = filename[:index] + '_aug_1' + filename[index:]
    pneumonia_aug_file_list.append(aug_0_filename.split('/')[-1])
    pneumonia_aug_file_list.append(aug_1_filename.split('/')[-1])
    videoWriter_0 = cv2.VideoWriter(aug_0_filename, fourcc, frameFPS, (frameWidth, frameHeight))
    videoWriter_1 = cv2.VideoWriter(aug_1_filename, fourcc, frameFPS, (frameWidth, frameHeight))

    while (cap.isOpened()):
        ret, frame = cap.read()
        if frame is None:
          break
        frame_0 = cv2.flip(frame,1)
        videoWriter_0.write(frame_0)

        random.seed(SEED)
        rand_angle = int(random.uniform(-angle,angle))
        h, w = frame.shape[:2]
        M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rand_angle, 1)
        frame_1 = cv2.warpAffine(frame, M, (w, h))
        frame_1 = np.uint8(frame_1)
        videoWriter_1.write(frame_1)
        SEED = SEED + 1
  
    cap.release()
    videoWriter_0.release()
    videoWriter_1.release()

    SEED = SEED + 1

# %%
normal_aug_dataset = pd.DataFrame()
normal_normal_dataset = pd.concat([normal_dataset, normal_dataset, normal_dataset, normal_dataset, normal_dataset],ignore_index = True)
normal_aug_dataset['filename'] = normal_aug_file_list
normal_aug_dataset['framerate'] = normal_normal_dataset['framerate'].tolist()
normal_aug_dataset['width'] = normal_normal_dataset['width'].tolist()
normal_aug_dataset['height'] = normal_normal_dataset['height'].tolist()
normal_aug_dataset['frame_count'] = normal_normal_dataset['frame_count'].tolist()
normal_aug_dataset['duration_secs'] = normal_normal_dataset['duration_secs'].tolist()
normal_aug_dataset['disease'] = normal_normal_dataset['disease'].tolist()
normal_aug_dataset['source'] = normal_normal_dataset['source'].tolist()
normal_aug_dataset
# Out:
#                                            filename  framerate  ...  disease  source
# 0   71_pocusatlas_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       4
# 1   71_pocusatlas_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       9
# 2   71_pocusatlas_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       5
# 3   71_pocusatlas_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       9
# 4   71_pocusatlas_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       4
# 5     236_clarius_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       7
# 6     236_clarius_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       7
# 7     236_clarius_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       8
# 8     236_clarius_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       7
# 9     236_clarius_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       1
# 10      152_radio_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       1
# 11      152_radio_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       4
# 12      152_radio_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       9
# 13      152_radio_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       5
# 14      152_radio_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       9
# 15    224_clarius_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       4
# 16    224_clarius_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       7
# 17    224_clarius_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       7
# 18    224_clarius_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       8
# 19    224_clarius_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       7
# 20  77_pocusatlas_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       1
# 21  77_pocusatlas_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       1
# 22  77_pocusatlas_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       4
# 23  77_pocusatlas_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       9
# 24  77_pocusatlas_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       5
# 25         190_uf_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       9
# 26         190_uf_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       4
# 27         190_uf_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       7
# 28         190_uf_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       7
# 29         190_uf_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       8
# 30         177_uf_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       7
# 31         177_uf_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       1
# 32         177_uf_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       1
# 33         177_uf_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       4
# 34         177_uf_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       9
# 35      239_paper_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       5
# 36      239_paper_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       9
# 37      239_paper_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       4
# 38      239_paper_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       7
# 39      239_paper_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       7
# 40         191_uf_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       8
# 41         191_uf_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       7
# 42         191_uf_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       1
# 43         191_uf_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       1
# 44         191_uf_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       4
# 45   20_butterfly_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       9
# 46   20_butterfly_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       5
# 47   20_butterfly_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       9
# 48   20_butterfly_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       4
# 49   20_butterfly_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       7
# 50   21_butterfly_normal_prc_convex_clean_aug_0.avi       15.0  ...        2       7
# 51   21_butterfly_normal_prc_convex_clean_aug_1.avi       15.0  ...        2       8
# 52   21_butterfly_normal_prc_convex_clean_aug_2.avi       15.0  ...        2       7
# 53   21_butterfly_normal_prc_convex_clean_aug_3.avi       15.0  ...        2       1
# 54   21_butterfly_normal_prc_convex_clean_aug_4.avi       15.0  ...        2       1
#
# [55 rows x 8 columns]

# %%
len(normal_aug_dataset)
# Out:
# 55

# %%
covid_aug_dataset = pd.DataFrame()
covid_aug_dataset['filename'] = covid_aug_file_list
covid_aug_dataset['framerate'] = covid_dataset['framerate'].tolist()
covid_aug_dataset['width'] = covid_dataset['width'].tolist()
covid_aug_dataset['height'] = covid_dataset['height'].tolist()
covid_aug_dataset['frame_count'] = covid_dataset['frame_count'].tolist()
covid_aug_dataset['duration_secs'] = covid_dataset['duration_secs'].tolist()
covid_aug_dataset['disease'] = covid_dataset['disease'].tolist()
covid_aug_dataset['source'] = covid_dataset['source'].tolist()
covid_aug_dataset
# Out:
#                                           filename  framerate  ...  disease  source
# 0     220_clarius_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       9
# 1      42_grepmed_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       2
# 2    12_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 3    89_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 4   74_pocusatlas_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       4
# 5    17_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 6       200_paper_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       8
# 7    14_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 8    11_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 9    16_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 10   90_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 11    7_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 12    218_clarius_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       9
# 13      201_paper_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       8
# 14     35_grepmed_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       2
# 15   13_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 16  61_pocusatlas_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       4
# 17   94_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 18     24_grepmed_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       2
# 19    221_clarius_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       9
# 20     26_grepmed_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       2
# 21     31_grepmed_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       2
# 22      199_paper_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       8
# 23  51_pocusatlas_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       4
# 24      205_paper_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       8
# 25      202_paper_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       8
# 26    2_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 27    1_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 28  54_pocusatlas_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       4
# 29  49_pocusatlas_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       4
# 30   84_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 31  56_pocusatlas_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       4
# 32   91_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 33   92_butterfly_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       1
# 34      203_paper_covid_prc_convex_clean_aug_0.avi       15.0  ...        0       8
#
# [35 rows x 8 columns]

# %%
pneumonia_aug_dataset = pd.DataFrame()
pneumonia_pneumonia_dataset = pd.concat([pneumonia_dataset, pneumonia_dataset],ignore_index = True)
pneumonia_aug_dataset['filename'] = pneumonia_aug_file_list
pneumonia_aug_dataset['framerate'] = pneumonia_pneumonia_dataset['framerate'].tolist()
pneumonia_aug_dataset['width'] = pneumonia_pneumonia_dataset['width'].tolist()
pneumonia_aug_dataset['height'] = pneumonia_pneumonia_dataset['height'].tolist()
pneumonia_aug_dataset['frame_count'] = pneumonia_pneumonia_dataset['frame_count'].tolist()
pneumonia_aug_dataset['duration_secs'] = pneumonia_pneumonia_dataset['duration_secs'].tolist()
pneumonia_aug_dataset['disease'] = pneumonia_pneumonia_dataset['disease'].tolist()
pneumonia_aug_dataset['source'] = pneumonia_pneumonia_dataset['source'].tolist()
pneumonia_aug_dataset
# Out:
#                                              filename  ...  source
# 0         184_uf_pneumonia_prc_convex_clean_aug_0.avi  ...       7
# 1         184_uf_pneumonia_prc_convex_clean_aug_1.avi  ...       2
# 2     37_grepmed_pneumonia_prc_convex_clean_aug_0.avi  ...       3
# 3     37_grepmed_pneumonia_prc_convex_clean_aug_1.avi  ...       4
# 4      131_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 5      131_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 6   68_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       5
# 7   68_pocusatlas_pneumonia_prc_convex_clean_aug_1...  ...       6
# 8   72_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       3
# 9   72_pocusatlas_pneumonia_prc_convex_clean_aug_1...  ...       9
# 10     151_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       3
# 11     151_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       2
# 12     153_radio_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 13     153_radio_pneumonia_prc_convex_clean_aug_1.avi  ...       2
# 14      158_core_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 15      158_core_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 16     123_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       2
# 17     123_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 18   232_clarius_pneumonia_prc_convex_clean_aug_0.avi  ...       9
# 19   232_clarius_pneumonia_prc_convex_clean_aug_1.avi  ...       6
# 20     129_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 21     129_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 22    25_grepmed_pneumonia_prc_convex_clean_aug_0.avi  ...       7
# 23    25_grepmed_pneumonia_prc_convex_clean_aug_1.avi  ...       2
# 24  79_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       3
# 25  79_pocusatlas_pneumonia_prc_convex_clean_aug_1...  ...       4
# 26    38_grepmed_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 27    38_grepmed_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 28  64_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       5
# 29  64_pocusatlas_pneumonia_prc_convex_clean_aug_1...  ...       6
# 30     121_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       3
# 31     121_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       9
# 32    27_grepmed_pneumonia_prc_convex_clean_aug_0.avi  ...       3
# 33    27_grepmed_pneumonia_prc_convex_clean_aug_1.avi  ...       2
# 34     127_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 35     127_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       2
# 36   234_clarius_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 37   234_clarius_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 38      170_core_pneumonia_prc_convex_clean_aug_0.avi  ...       2
# 39      170_core_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 40  80_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       9
# 41  80_pocusatlas_pneumonia_prc_convex_clean_aug_1...  ...       6
# 42      43_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 43      43_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       3
#
# [44 rows x 8 columns]

# %%
video_dataset_copy = pd.concat([video_dataset, normal_aug_dataset,covid_aug_dataset,pneumonia_aug_dataset],ignore_index = True)
video_dataset_copy.reset_index(drop=True)
video_dataset = video_dataset_copy
video_dataset
# Out:
#                                               filename  ...  source
# 0               220_clarius_covid_prc_convex_clean.avi  ...       9
# 1                184_uf_pneumonia_prc_convex_clean.avi  ...       7
# 2                42_grepmed_covid_prc_convex_clean.avi  ...       2
# 3            71_pocusatlas_normal_prc_convex_clean.avi  ...       4
# 4            37_grepmed_pneumonia_prc_convex_clean.avi  ...       2
# ..                                                 ...  ...     ...
# 197      170_core_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 198  80_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       9
# 199  80_pocusatlas_pneumonia_prc_convex_clean_aug_1...  ...       6
# 200      43_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 201      43_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       3
#
# [202 rows x 8 columns]

# %%
X_train = video_dataset
y_train = video_dataset['disease']
X_train['disease'].value_counts()
# Out:
# 0    70
# 2    66
# 1    66
# Name: disease, dtype: int64

# %%
print(len(glob('data/video/clean_copy2/*')))
# Out:
# 377

# %%
# separating the target
X = video_dataset
y = video_dataset['disease']

# creating the training and validation set
X_training, X_test, y_training, y_test = train_test_split(X, y, test_size=train_test_ratio, stratify = y)
X_train, X_val, y_train, y_val = train_test_split(X_training, y_training, shuffle=True, test_size=train_val_ratio, stratify = y_training)

X_train = X_train.reset_index(drop = True)
X_val = X_val.reset_index(drop = True)
X_test = X_test.reset_index(drop = True)
y_train = y_train.reset_index(drop = True)
y_val = y_val.reset_index(drop = True)
y_test = y_test.reset_index(drop = True)

# %%
print("X_train size : {}".format(X_train.shape))
print("y_train size : {}".format(y_train.shape))
print("X_val size : {}".format(X_val.shape))
print("y_val size : {}".format(y_val.shape))
print("X_test size : {}".format(X_test.shape))
print("y_test size : {}".format(y_test.shape))
# Out:
# X_train size : (112, 8)
# y_train size : (112,)
# X_val size : (29, 8)
# y_val size : (29,)
# X_test size : (61, 8)
# y_test size : (61,)

# %% [markdown]
# test 영상만 이후 evaluate 하는 과정에서 frame을 추출하므로 파일 이름을 csv 파일로 저장

# %%
# storing the frames from training videos
test_dataset = pd.DataFrame()
test_dataset['filename'] = X_test['filename']
test_dataset.to_csv('data/test_dataset.csv', header=True, index=False)

# %% [markdown]
# train 영상과 val 영상은 지금 frame을 추출
#
# 다음 과정에서 생성되는 폴더는 코드를 다시 실행하는 경우 중복이나 필요없는 데이터를 제거하기 위해 이 폴더를 삭제하고 진행 (다음 코드 참고)

# %%
# create images_14frames_train and images_14frames_val folders, if they do not exist
if not os.path.exists('data/images_captured_train'):
    os.makedirs('data/images_captured_train')
if not os.path.exists('data/images_captured_val'):
    os.makedirs('data/images_captured_val')

files = glob('data/images_captured_train/*')
for f in files:
    os.remove(f)
files = glob('data/images_captured_val/*')
for f in files:
    os.remove(f)

# %% [markdown]
# Converts a PIL Image instance to a Numpy array.
# (tf.keras.image.img_to_array와 동일)

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
	  (im_height, im_width, channels)).astype(np.uint8)
   
def featuring_space(frame_count):
  if frame_count<=28:
    return 1
  elif frame_count<=56:
    return 2
  elif frame_count<=84:
    return 3
  elif frame_count<=112:
    return 4
  else : return 5

# %% [markdown]
# **모든 영상에서 뽑아내는 frame 길이를 동일하게 맞춘 뒤에 LSTM을 통과시키고자**
#
# **모든 영상에 대해 frames에 해당하는 프레임을 capture함**

# %%
train_label=[]
for i in tqdm(range(X_train.shape[0])):

    count = 0
    current = 0
    videoFile = X_train['filename'][i]
    disease = videoFile.split('_')[2]
    if disease == 'covid' :
      disease_num = 0
    elif disease == 'pneumonia' :
      disease_num = 1
    else : disease_num = 2
    cap = cv2.VideoCapture('data/video/clean_copy2/' + videoFile) # capturing the video from the given path
    frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    space = featuring_space(frame_count)
    capture_epoch = math.floor( frame_count / (14*space) )
    capture_num = capture_epoch*14

    while(cap.isOpened()):
      if(count==capture_num):
        break
      cap.get(1)
      ret, frame = cap.read()
      if (ret != True):
        break
      if current%space==0 :
        filename = 'data/images_captured_train/' + videoFile + "_frame_%d.jpg" % count; count += 1
        cv2.imwrite(filename, frame)
        if(count%14==0):
          train_label.append(disease_num)
      current=current+1
    cap.release()

len(os.listdir('data/images_captured_train/'))
# Out:
# 100%|██████████| 112/112 [01:00<00:00,  1.86it/s]
# 3094

# %%
val_label=[]
for i in tqdm(range(X_val.shape[0])):

    count = 0
    current = 0
    videoFile = X_val['filename'][i]
    disease = videoFile.split('_')[2]
    if disease == 'covid' :
      disease_num = 0
    elif disease == 'pneumonia' :
      disease_num = 1
    else : disease_num = 2
    cap = cv2.VideoCapture('data/video/clean_copy2/' + videoFile) # capturing the video from the given path
    frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    space = featuring_space(frame_count)
    capture_epoch = math.floor( frame_count / (14*space) )
    capture_num = capture_epoch*14

    while(cap.isOpened()):
      if(count==capture_num):
        break
      cap.get(1)
      ret, frame = cap.read()
      if (ret != True):
        break
      if current%space==0 :
        filename = 'data/images_captured_val/' + videoFile + "_frame_%d.jpg" % count; count += 1
        cv2.imwrite(filename, frame)
        if(count%14==0):
          val_label.append(disease_num)
      current=current+1
    cap.release()

len(os.listdir('data/images_captured_val/'))
# Out:
# 100%|██████████| 29/29 [00:15<00:00,  1.85it/s]
# 756

# %%
X_val
# Out:
#                                              filename  ...  source
# 0            191_uf_normal_prc_convex_clean_aug_0.avi  ...       8
# 1          205_paper_covid_prc_convex_clean_aug_0.avi  ...       8
# 2         239_paper_normal_prc_convex_clean_aug_1.avi  ...       9
# 3       43_litfl_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 4     77_pocusatlas_normal_prc_convex_clean_aug_0.avi  ...       1
# 5       236_clarius_normal_prc_convex_clean_aug_3.avi  ...       7
# 6                  177_uf_normal_prc_convex_clean.avi  ...       7
# 7         152_radio_normal_prc_convex_clean_aug_4.avi  ...       9
# 8       43_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 9             92_butterfly_covid_prc_convex_clean.avi  ...       1
# 10  64_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       5
# 11     123_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       2
# 12        184_uf_pneumonia_prc_convex_clean_aug_1.avi  ...       2
# 13           49_pocusatlas_covid_prc_convex_clean.avi  ...       4
# 14              31_grepmed_covid_prc_convex_clean.avi  ...       2
# 15      11_butterfly_covid_prc_convex_clean_aug_0.avi  ...       1
# 16      17_butterfly_covid_prc_convex_clean_aug_0.avi  ...       1
# 17          77_pocusatlas_normal_prc_convex_clean.avi  ...       4
# 18             220_clarius_covid_prc_convex_clean.avi  ...       9
# 19  72_pocusatlas_pneumonia_prc_convex_clean_aug_0...  ...       3
# 20          38_grepmed_pneumonia_prc_convex_clean.avi  ...       2
# 21      224_clarius_normal_prc_convex_clean_aug_0.avi  ...       4
# 22      16_butterfly_covid_prc_convex_clean_aug_0.avi  ...       1
# 23     21_butterfly_normal_prc_convex_clean_aug_1.avi  ...       8
# 24    71_pocusatlas_normal_prc_convex_clean_aug_3.avi  ...       9
# 25     127_litfl_pneumonia_prc_convex_clean_aug_0.avi  ...       4
# 26      158_core_pneumonia_prc_convex_clean_aug_1.avi  ...       3
# 27             218_clarius_covid_prc_convex_clean.avi  ...       9
# 28        31_grepmed_covid_prc_convex_clean_aug_0.avi  ...       2
#
# [29 rows x 8 columns]

# %%
train_images = glob("data/images_captured_train/*.jpg")

train_image_name = []
train_image_class = []
for i in tqdm(range(len(train_images))):
    # creating the image name
    train_image_name.append(train_images[i].split('/')[2])
    # creating the class of image
    disease = train_images[i].split('/')[2].split('_')[2]
    if disease == 'covid':
        train_image_class.append(0)
    elif disease == 'pneumonia':
        train_image_class.append(1)
    else:
        train_image_class.append(2)

train_image_dataset = pd.DataFrame()
train_image_dataset['filename'] = train_image_name
train_image_dataset['disease'] = train_image_class # 

train_image_dataset.to_csv('data/image_files_clean_train.csv', header=True, index=False)
# Out:
# 100%|██████████| 3094/3094 [00:00<00:00, 338564.48it/s]

# %%
train_image_dataset
# Out:
#                                                filename  disease
# 0     121_litfl_pneumonia_prc_convex_clean.avi_frame...        1
# 1     121_litfl_pneumonia_prc_convex_clean.avi_frame...        1
# 2     121_litfl_pneumonia_prc_convex_clean.avi_frame...        1
# 3     121_litfl_pneumonia_prc_convex_clean.avi_frame...        1
# 4     121_litfl_pneumonia_prc_convex_clean.avi_frame...        1
# ...                                                 ...      ...
# 3089  152_radio_normal_prc_convex_clean_aug_2.avi_fr...        2
# 3090  152_radio_normal_prc_convex_clean_aug_2.avi_fr...        2
# 3091  152_radio_normal_prc_convex_clean_aug_2.avi_fr...        2
# 3092  152_radio_normal_prc_convex_clean_aug_2.avi_fr...        2
# 3093  152_radio_normal_prc_convex_clean_aug_2.avi_fr...        2
#
# [3094 rows x 2 columns]

# %%
val_images = glob("data/images_captured_val/*.jpg")

val_image_name = []
val_image_class = []
for i in tqdm(range(len(val_images))):
    # creating the image name
    val_image_name.append(val_images[i].split('/')[2])
    # creating the class of image
    disease = val_images[i].split('/')[2].split('_')[2]
    if disease == 'covid':
        val_image_class.append(0)
    elif disease == 'pneumonia':
      val_image_class.append(1)
    else:
        val_image_class.append(2)

val_image_dataset = pd.DataFrame()
val_image_dataset['filename'] = val_image_name
val_image_dataset['disease'] = val_image_class 

val_image_dataset.to_csv('data/image_files_clean_val.csv', header=True, index=False)
# Out:
# 100%|██████████| 756/756 [00:00<00:00, 233910.73it/s]

# %%
val_image_dataset
# Out:
#                                               filename  disease
# 0    191_uf_normal_prc_convex_clean_aug_0.avi_frame...        2
# 1    191_uf_normal_prc_convex_clean_aug_0.avi_frame...        2
# 2    191_uf_normal_prc_convex_clean_aug_0.avi_frame...        2
# 3    191_uf_normal_prc_convex_clean_aug_0.avi_frame...        2
# 4    191_uf_normal_prc_convex_clean_aug_0.avi_frame...        2
# ..                                                 ...      ...
# 751  31_grepmed_covid_prc_convex_clean_aug_0.avi_fr...        0
# 752  31_grepmed_covid_prc_convex_clean_aug_0.avi_fr...        0
# 753  31_grepmed_covid_prc_convex_clean_aug_0.avi_fr...        0
# 754  31_grepmed_covid_prc_convex_clean_aug_0.avi_fr...        0
# 755  31_grepmed_covid_prc_convex_clean_aug_0.avi_fr...        0
#
# [756 rows x 2 columns]

# %%
# creating an empty list
train_images = []

# for loop to read and store frames
for i in tqdm(range(train_image_dataset.shape[0])):
    # loading the image and keeping the target size as (224,224,3)
    img = image.load_img('data/images_captured_train/'+train_image_dataset['filename'][i], target_size=(height,width,channels))

    # converting it to array
    img_np = image.img_to_array(img)

    # normalizing the pixel value
    img_np = img_np / 255

    # appending the image to the images list
    train_images.append(img_np)
    
# converting the list to numpy array
X_train = np.array(train_images)
print(X_train.shape)
# Out:
# 100%|██████████| 3094/3094 [00:20<00:00, 149.47it/s]
# (3094, 224, 224, 3)

# %%
# creating an empty list
val_images = []

# for loop to read and store frames
for i in tqdm(range(val_image_dataset.shape[0])):
    # loading the image and keeping the target size as (224,224,3)
    img = image.load_img('data/images_captured_val/'+val_image_dataset['filename'][i], target_size=(height,width,channels))
    # converting it to array
    img = image.img_to_array(img)
    # normalizing the pixel value
    img = img/255
    # appending the image to the images list
    val_images.append(img)
    
# converting the list to numpy array
X_val = np.array(val_images)
print(X_val.shape)
# Out:
# 100%|██████████| 756/756 [00:05<00:00, 135.76it/s]
# (756, 224, 224, 3)

# %%
X_train=X_train.reshape(-1,14,224,224,3)
X_val=X_val.reshape(-1,14,224,224,3)
train_label = np.array(train_label)
val_label = np.array(val_label)
print(X_train.shape)
print(X_val.shape)
print(train_label.shape)
print(val_label.shape)
print(X_test.shape)
# Out:
# (221, 14, 224, 224, 3)
# (54, 14, 224, 224, 3)
# (221,)
# (54,)
# (61, 8)

# %%
np.save('data/X_train_save_0', X_train)
np.save('data/X_val_save_0', X_val)
np.save('data/y_train_save_0', train_label)
np.save('data/y_val_save_0', val_label)
